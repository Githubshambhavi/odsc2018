# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import numpy as np

from skimage import io
from skimage import data
from scipy.signal import convolve2d
from skimage.measure import block_reduce

# %%
image = io.imread('dog.jpg', as_grey=True)
kernel = [[1.0, -0.25, 0.0],
          [-0.25, 2.5, -0.25],
          [0.0, -0.25, -1.0]]
new_image = convolve2d(image, kernel).clip(0.0, 1.0)
io.imshow(new_image)
# Out:
# /Users/shambhavi.srivastava/.pyenv/versions/3.6.2/envs/venv/lib/python3.6/site-packages/skimage/io/_io.py:49: UserWarning: `as_grey` has been deprecated in favor of `as_gray`
#   warn('`as_grey` has been deprecated in favor of `as_gray`')

# %%
###### activation relu will reduce the blackness
###### Applying transformation on input data before it goes to next layer; Do Pooling reduce the input image size by factor 2 or whatever
###### factor you decide (max pool with 2x2 filters by stride 2)
###### Max pooling  (1,1,5,6) --> biggest number 
###### Sum pooling  
###### Average pooling

# %%
new_image = block_reduce(image, block_size=(7, 7), func=np.max)

io.imsave('out.png', new_image)
# Out:
# /Users/shambhavi.srivastava/.pyenv/versions/3.6.2/envs/venv/lib/python3.6/site-packages/skimage/util/dtype.py:141: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))

# %%
io.imshow(new_image)
